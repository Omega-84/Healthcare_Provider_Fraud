# %%
import numpy as np
import pandas as pd
import joblib
import time
import os
from sklearn.model_selection import train_test_split, cross_val_score, GridSearchCV, StratifiedKFold
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import make_pipeline
from sklearn.compose import make_column_transformer
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier
from catboost import CatBoostClassifier
import sklearn.metrics as metrics
import optuna
from datetime import datetime
from warnings import filterwarnings
filterwarnings("ignore")
pd.set_option("display.max_columns", None)
pd.set_option("display.max_rows", 20)

# %% [markdown]
# ### Training Data

# %%
train = pd.read_csv("../data/processed/training_data.csv")

# %%
train.head()
# Out:
#    Provider  PotentialFraud  count_unique_beneficiary  count_unique_claims  \
# 0  PRV51001               0                        24                   25
# 1  PRV51003               1                       117                  132
# 2  PRV51004               0                       138                  149
# 3  PRV51005               1                       495                 1165
# 4  PRV51007               0                        58                   72
#
#    count_dead_beneficiary  count_unique_states  count_unique_counties  \
# 0                       0                    1                      7
# 1                       1                    3                     23
# 2                       1                    9                     28
# 3                       4                    4                     26
# 4                       1                    2                      6
#
#    mean_hospital_stay_days  max_hospital_stay_days  total_top_diagnosis_codes  \
# 0                 1.200000                    15.0                          3
# 1                 2.893939                    28.0                         26
# 2                 0.000000                     0.0                          7
# 3                 0.000000                     0.0                         82
# 4                 0.263889                     8.0                          4
#
#    mean_total_diagnosis  mean_total_procedures  mean_number_of_physicians  \
# 0              3.200000               0.120000                   1.600000
# 1              5.250000               0.363636                   1.530303
# 2              2.583893               0.000000                   1.604027
# 3              2.588841               0.000000                   1.599142
# 4              2.986111               0.013889                   1.527778
#
#    mean_difference_stay_vs_claim  patients_under_top_attending_physician  \
# 0                            0.0                                       0
# 1                            0.0                                       0
# 2                            0.0                                       0
# 3                            0.0                                       0
# 4                            0.0                                       0
#
#    patients_under_top_operating_physician  mean_claim_amount  \
# 0                                       0        4185.600000
# 1                                       0        4588.409091
# 2                                       0         350.134228
# 3                                       0         241.124464
# 4                                       0         468.194444
#
#    total_claim_amount  std_claim_amount   mean_age  count_of_males  \
# 0              104640      10796.091144  77.880000               9
# 1              605670       7309.794729  69.083333              54
# 2               52170        689.963754  71.261745              46
# 3              280910        491.556392  69.526180             511
# 4               33710       1433.769116  68.305556              34
#
#    count_of_females  count_of_black_people  count_of_white_people  \
# 0                16                      4                     21
# 1                78                     24                    107
# 2               103                     24                    120
# 3               654                    262                    893
# 4                38                     14                     58
#
#    count_of_hispanic_people  count_of_other_people  count_alzheimer  \
# 0                         0                      0               15
# 1                         1                      0               56
# 2                         0                      5               64
# 3                         0                     10              426
# 4                         0                      0               26
#
#    count_heartfailure  count_kidneydisease  count_cancer  \
# 0                  19                   17             5
# 1                  80                   64            10
# 2                  88                   50            16
# 3                 680                  507           165
# 4                  40                   22            12
#
#    count_obstrpulmonary  count_depression  count_diabetes  \
# 0                    10                 9              21
# 1                    41                54             100
# 2                    41                63             105
# 3                   295               485             799
# 4                    16                29              49
#
#    count_ischemicheart  count_osteoporasis  count_rheumatoidarthritis  \
# 0                   23                   6                          8
# 1                  112                  33                         38
# 2                  108                  49                         46
# 3                  895                 344                        331
# 4                   51                  21                         22
#
#    count_stroke  count_renal_disease  mean_annual_inpatient_reimbursement  \
# 0             6                    8                         17606.000000
# 1            12                   29                          7568.181818
# 2            17                   23                          4351.879195
# 3           124                  259                          3623.991416
# 4            12                   11                          3050.000000
#
#    mean_annual_inpatient_deductible  mean_annual_outpatient_reimbursement  \
# 0                        897.120000                           2615.200000
# 1                        931.424242                           2678.181818
# 2                        434.953020                           2194.899329
# 3                        379.162232                           2109.733906
# 4                        445.000000                           1729.722222
#
#    mean_annual_outpatient_deductible  count_inpatient  count_outpatient  \
# 0                         463.920000                5                20
# 1                         737.121212               62                70
# 2                         622.751678                0               149
# 3                         636.328755                0              1165
# 4                         469.722222                3                69
#
#    claims_per_bene
# 0         1.041667
# 1         1.128205
# 2         1.079710
# 3         2.353535
# 4         1.241379

# %%
standard_scaling_column = ['mean_age','mean_claim_amount','total_claim_amount','std_claim_amount','mean_hospital_stay_days',
                           'max_hospital_stay_days','mean_annual_inpatient_reimbursement','mean_annual_inpatient_deductible',
                           'mean_annual_outpatient_reimbursement',  'mean_annual_outpatient_deductible']

# %%
min_max_cols = [
    'count_unique_beneficiary', 'count_unique_claims', 'claims_per_bene',
    'count_unique_states', 'count_unique_counties',
    'total_top_diagnosis_codes', 'mean_total_diagnosis', 'mean_total_procedures',
    'mean_number_of_physicians', 'mean_difference_stay_vs_claim',
    'count_inpatient', 'count_outpatient',
    'count_of_males', 'count_of_females', 'count_of_black_people', 'count_of_white_people' ,
    'count_of_hispanic_people', 'count_of_other_people'
]

# %%
X = train.drop(['Provider','PotentialFraud'],axis=1)

# %%
y = train[['PotentialFraud']]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42, stratify=y)

# %%
preprocessor = make_column_transformer(
    (StandardScaler(), standard_scaling_column),
    (MinMaxScaler(), min_max_cols),
    remainder='passthrough'
)

# %% [markdown]
# ## Random Forest

# %%
rf = RandomForestClassifier(
    class_weight='balanced',   
    random_state=42,
    n_jobs=-1
)

# %%
pipe_rf = make_pipeline(preprocessor, rf)

# %%
start_train = time.time()
pipe_rf.fit(X_train, y_train)
train_time = time.time() - start_train
print(f"⏱ Training time: {train_time:.2f} seconds")
# Out:
# ⏱ Training time: 0.36 seconds

# %%
y_pred_train_rf = pipe_rf.predict_proba(X_train)[:, 1]
y_pred_test_rf = pipe_rf.predict_proba(X_test)[:, 1]
print(f"Training roc-auc score: {metrics.roc_auc_score(y_train, y_pred_train_rf)}")
print(f"Testing roc-auc score: {metrics.roc_auc_score(y_test, y_pred_test_rf)}")
# Out:
# Training roc-auc score: 1.0
# Testing roc-auc score: 0.9491128921896788

# %%
print(metrics.classification_report(y_test, pipe_rf.predict(X_test)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      0.98      0.97      1619
#            1       0.75      0.55      0.63       167
#
#     accuracy                           0.94      1786
#    macro avg       0.85      0.77      0.80      1786
# weighted avg       0.94      0.94      0.94      1786

# %% [markdown]
# Model is overfitted and only capturing 55% fraudsters

# %% [markdown]
# ## XGBoost

# %%
scale_pos_weight = round((y_train==0).sum()/(y_train==1).sum())['PotentialFraud']

# %%
xgb = XGBClassifier(
    objective='binary:logistic',
    eval_metric='auc',
    n_jobs=-1,
    random_state=42,
    scale_pos_weight=scale_pos_weight)

# %%
pipe_xgb = make_pipeline(preprocessor, xgb)

# %%
start_train = time.time()
pipe_xgb.fit(X_train, y_train)
train_time = time.time() - start_train
print(f"⏱ Training time: {train_time:.2f} seconds")
# Out:
# ⏱ Training time: 1.70 seconds

# %%
y_pred_train_xgb = pipe_xgb.predict_proba(X_train)[:, 1]
y_pred_test_xgb = pipe_xgb.predict_proba(X_test)[:, 1]
print(f"Training roc-auc score: {metrics.roc_auc_score(y_train, y_pred_train_xgb)}")
print(f"Testing roc-auc score: {metrics.roc_auc_score(y_test, y_pred_test_xgb)}")
# Out:
# Training roc-auc score: 1.0
# Testing roc-auc score: 0.9506200693116545

# %%
print(metrics.classification_report(y_test, pipe_xgb.predict(X_test)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.97      0.97      1619
#            1       0.69      0.68      0.68       167
#
#     accuracy                           0.94      1786
#    macro avg       0.83      0.83      0.83      1786
# weighted avg       0.94      0.94      0.94      1786

# %% [markdown]
# The model is overfitted but now capturing more than Random Forest so we will fine tune XGBoost.

# %% [markdown]
# ## Fine tuning

# %%
def objective(trial):
    params = {
        "n_estimators": trial.suggest_int("n_estimators", 100, 600),
        "learning_rate": trial.suggest_float("learning_rate", 0.01, 0.1),
        "max_depth": trial.suggest_int("max_depth", 3, 7),
        "subsample": trial.suggest_float("subsample", 0.5, 0.9),
        "colsample_bytree": trial.suggest_float("colsample_bytree", 0.5, 0.9),
        "min_child_weight": trial.suggest_int("min_child_weight", 1, 10),
        "gamma": trial.suggest_float("gamma", 0, 1),
        "reg_alpha": trial.suggest_float("reg_alpha", 0, 5),
        "reg_lambda": trial.suggest_float("reg_lambda", 0, 5),
        "random_state": 42,
        "n_jobs": -1,
        "scale_pos_weight": scale_pos_weight,
        "objective": "binary:logistic",
        "eval_metric": "auc"
    }
    
    model = XGBClassifier(**params)
    cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)
    
    pipeline = make_pipeline(preprocessor, model)
    cv_scores = cross_val_score(pipeline, X_train, y_train, cv=cv, scoring='roc_auc')
    
    return cv_scores.mean()

# %%
study = optuna.create_study(
    direction='maximize',  # Maximize AUC
    study_name='xgboost_fraud_detection'
)
# Out:
# [I 2025-12-29 21:13:19,087] A new study created in memory with name: xgboost_fraud_detection

# %%
study.optimize(objective, n_trials=100, show_progress_bar=True)
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]
# [I 2025-12-29 21:13:46,772] Trial 1 finished with value: 0.9422322980851853 and parameters: {'n_estimators': 376, 'learning_rate': 0.07448633498465948, 'max_depth': 6, 'subsample': 0.7638955606563205, 'colsample_bytree': 0.7900829799946718, 'min_child_weight': 9, 'gamma': 0.24095129886647548, 'reg_alpha': 1.671623137790793, 'reg_lambda': 4.371861095710674}. Best is trial 1 with value: 0.9422322980851853.
# [I 2025-12-29 21:13:48,686] Trial 2 finished with value: 0.9458260002699369 and parameters: {'n_estimators': 127, 'learning_rate': 0.021191236723614205, 'max_depth': 7, 'subsample': 0.6952233781189163, 'colsample_bytree': 0.7132649845811445, 'min_child_weight': 2, 'gamma': 0.6674373012846787, 'reg_alpha': 3.3261514924782287, 'reg_lambda': 0.40017976653055287}. Best is trial 2 with value: 0.9458260002699369.
# [I 2025-12-29 21:13:52,820] Trial 3 finished with value: 0.9458909454874433 and parameters: {'n_estimators': 473, 'learning_rate': 0.018504907444419814, 'max_depth': 7, 'subsample': 0.7809068572531992, 'colsample_bytree': 0.5575636827287759, 'min_child_weight': 6, 'gamma': 0.3806060829739435, 'reg_alpha': 2.4912825690337175, 'reg_lambda': 3.0259372519547}. Best is trial 3 with value: 0.9458909454874433.
# [I 2025-12-29 21:13:55,007] Trial 4 finished with value: 0.943020059519753 and parameters: {'n_estimators': 500, 'learning_rate': 0.07981709354102468, 'max_depth': 6, 'subsample': 0.8861244650295255, 'colsample_bytree': 0.7493068526627298, 'min_child_weight': 7, 'gamma': 0.6738540583468666, 'reg_alpha': 3.600394263638127, 'reg_lambda': 1.7876059143751615}. Best is trial 3 with value: 0.9458909454874433.
# [I 2025-12-29 21:13:56,386] Trial 5 finished with value: 0.9452759035870875 and parameters: {'n_estimators': 444, 'learning_rate': 0.040206460334627867, 'max_depth': 3, 'subsample': 0.7602356043565058, 'colsample_bytree': 0.6733587111283401, 'min_child_weight': 9, 'gamma': 0.8991075626290013, 'reg_alpha': 0.011985090950014654, 'reg_lambda': 1.5488913293575064}. Best is trial 3 with value: 0.9458909454874433.
# [I 2025-12-29 21:14:01,274] Trial 6 finished with value: 0.9454546365673646 and parameters: {'n_estimators': 222, 'learning_rate': 0.02865953385687034, 'max_depth': 6, 'subsample': 0.8438993298636905, 'colsample_bytree': 0.8495563072305012, 'min_child_weight': 8, 'gamma': 0.6077605774659358, 'reg_alpha': 0.5688255416504534, 'reg_lambda': 4.171456859413969}. Best is trial 3 with value: 0.9458909454874433.
# [I 2025-12-29 21:14:03,625] Trial 7 finished with value: 0.9427616817871428 and parameters: {'n_estimators': 296, 'learning_rate': 0.07251959080228862, 'max_depth': 6, 'subsample': 0.886848639493814, 'colsample_bytree': 0.8823083828309086, 'min_child_weight': 10, 'gamma': 0.11368718095983577, 'reg_alpha': 1.7896279298171958, 'reg_lambda': 0.33667324238186525}. Best is trial 3 with value: 0.9458909454874433.
# [I 2025-12-29 21:14:09,059] Trial 8 finished with value: 0.9469046120458678 and parameters: {'n_estimators': 416, 'learning_rate': 0.01626497102571067, 'max_depth': 6, 'subsample': 0.6904470915878432, 'colsample_bytree': 0.7717785872599565, 'min_child_weight': 2, 'gamma': 0.04488404187805195, 'reg_alpha': 1.9423264861694216, 'reg_lambda': 1.4786007679847408}. Best is trial 8 with value: 0.9469046120458678.
# [I 2025-12-29 21:14:10,728] Trial 9 finished with value: 0.9449382819985488 and parameters: {'n_estimators': 243, 'learning_rate': 0.036698491088412145, 'max_depth': 5, 'subsample': 0.8036439050496009, 'colsample_bytree': 0.7848002027411933, 'min_child_weight': 10, 'gamma': 0.9948055657387559, 'reg_alpha': 2.0481834719615692, 'reg_lambda': 0.35594616564837755}. Best is trial 8 with value: 0.9469046120458678.
# [I 2025-12-29 21:14:14,241] Trial 10 finished with value: 0.9431224217349994 and parameters: {'n_estimators': 255, 'learning_rate': 0.04671730302823345, 'max_depth': 6, 'subsample': 0.5908961575894757, 'colsample_bytree': 0.5904072043423614, 'min_child_weight': 9, 'gamma': 0.33911706748850057, 'reg_alpha': 3.871890045234085, 'reg_lambda': 3.4810235891046597}. Best is trial 8 with value: 0.9469046120458678.
# [I 2025-12-29 21:14:18,855] Trial 11 finished with value: 0.9411067814299441 and parameters: {'n_estimators': 591, 'learning_rate': 0.09516667925629085, 'max_depth': 4, 'subsample': 0.5101221352885548, 'colsample_bytree': 0.6422074231985003, 'min_child_weight': 1, 'gamma': 0.06988383353083077, 'reg_alpha': 4.968911873677811, 'reg_lambda': 1.8105350227245027}. Best is trial 8 with value: 0.9469046120458678.
# [I 2025-12-29 21:14:24,196] Trial 12 finished with value: 0.9457525025958041 and parameters: {'n_estimators': 447, 'learning_rate': 0.010618849738317225, 'max_depth': 7, 'subsample': 0.6755092442137204, 'colsample_bytree': 0.5000924885587952, 'min_child_weight': 4, 'gamma': 0.4022648626378587, 'reg_alpha': 2.6356657403038874, 'reg_lambda': 3.044323787201089}. Best is trial 8 with value: 0.9469046120458678.
# [I 2025-12-29 21:14:28,198] Trial 13 finished with value: 0.9448007745318533 and parameters: {'n_estimators': 543, 'learning_rate': 0.013822376938416508, 'max_depth': 7, 'subsample': 0.6488927966995145, 'colsample_bytree': 0.5099174089826444, 'min_child_weight': 5, 'gamma': 0.19902011736030664, 'reg_alpha': 1.2354159668990095, 'reg_lambda': 2.572513503580682}. Best is trial 8 with value: 0.9469046120458678.
# [I 2025-12-29 21:14:36,200] Trial 14 finished with value: 0.9435927400333813 and parameters: {'n_estimators': 388, 'learning_rate': 0.05649074523258152, 'max_depth': 5, 'subsample': 0.752270341996311, 'colsample_bytree': 0.593584373291618, 'min_child_weight': 3, 'gamma': 0.5294002688802955, 'reg_alpha': 2.9185210994938195, 'reg_lambda': 1.23903578498639}. Best is trial 8 with value: 0.9469046120458678.
# [I 2025-12-29 21:14:40,378] Trial 15 finished with value: 0.9451112019809628 and parameters: {'n_estimators': 458, 'learning_rate': 0.026893050606656654, 'max_depth': 7, 'subsample': 0.6058179483620125, 'colsample_bytree': 0.5940645814415314, 'min_child_weight': 5, 'gamma': 0.01595345710882279, 'reg_alpha': 2.3906817859821237, 'reg_lambda': 3.4932060203222637}. Best is trial 8 with value: 0.9469046120458678.
# [I 2025-12-29 21:14:42,464] Trial 16 finished with value: 0.9435793100038353 and parameters: {'n_estimators': 334, 'learning_rate': 0.05371795683211146, 'max_depth': 4, 'subsample': 0.7236127839844838, 'colsample_bytree': 0.8195238465831058, 'min_child_weight': 6, 'gamma': 0.3813445493024584, 'reg_alpha': 1.3685841710243982, 'reg_lambda': 2.32185977092362}. Best is trial 8 with value: 0.9469046120458678.
# [I 2025-12-29 21:14:47,698] Trial 17 finished with value: 0.9462673872111373 and parameters: {'n_estimators': 516, 'learning_rate': 0.023523810816306882, 'max_depth': 7, 'subsample': 0.7979621729361694, 'colsample_bytree': 0.7243545891234032, 'min_child_weight': 3, 'gamma': 0.22470688852107654, 'reg_alpha': 0.8627252470887519, 'reg_lambda': 0.8574053816334082}. Best is trial 8 with value: 0.9469046120458678.
# [I 2025-12-29 21:14:52,143] Trial 18 finished with value: 0.9455542593238482 and parameters: {'n_estimators': 597, 'learning_rate': 0.03276099954287037, 'max_depth': 5, 'subsample': 0.8259445145704822, 'colsample_bytree': 0.7272857363068898, 'min_child_weight': 1, 'gamma': 0.19645389027408391, 'reg_alpha': 0.817948485591957, 'reg_lambda': 0.9933581973306087}. Best is trial 8 with value: 0.9469046120458678.
# [I 2025-12-29 21:14:56,505] Trial 19 finished with value: 0.9430040236635785 and parameters: {'n_estimators': 517, 'learning_rate': 0.061018808297651245, 'max_depth': 6, 'subsample': 0.6323298074482191, 'colsample_bytree': 0.6627109316277086, 'min_child_weight': 3, 'gamma': 0.12341843158233502, 'reg_alpha': 0.04303688916140025, 'reg_lambda': 1.1296935548719944}. Best is trial 8 with value: 0.9469046120458678.
# [I 2025-12-29 21:14:58,996] Trial 20 finished with value: 0.9458219244898259 and parameters: {'n_estimators': 412, 'learning_rate': 0.023280474141420822, 'max_depth': 4, 'subsample': 0.5342328098712005, 'colsample_bytree': 0.7725127550766636, 'min_child_weight': 3, 'gamma': 0.009716043053375728, 'reg_alpha': 0.8954201974075449, 'reg_lambda': 0.8328512989627992}. Best is trial 8 with value: 0.9469046120458678.
# [I 2025-12-29 21:15:02,646] Trial 21 finished with value: 0.9440885152534401 and parameters: {'n_estimators': 549, 'learning_rate': 0.044517948593134904, 'max_depth': 5, 'subsample': 0.714797626792615, 'colsample_bytree': 0.6958024804960306, 'min_child_weight': 2, 'gamma': 0.2442469712661416, 'reg_alpha': 4.282440675747498, 'reg_lambda': 2.2168915136314298}. Best is trial 8 with value: 0.9469046120458678.
# [I 2025-12-29 21:15:12,112] Trial 22 finished with value: 0.9454541688548929 and parameters: {'n_estimators': 503, 'learning_rate': 0.017980654128754072, 'max_depth': 7, 'subsample': 0.7829041295754945, 'colsample_bytree': 0.5521936335411669, 'min_child_weight': 4, 'gamma': 0.314481683378877, 'reg_alpha': 2.325981788059498, 'reg_lambda': 4.945631554514579}. Best is trial 8 with value: 0.9469046120458678.
# [I 2025-12-29 21:15:20,915] Trial 23 finished with value: 0.9463181674223564 and parameters: {'n_estimators': 475, 'learning_rate': 0.01206000176160351, 'max_depth': 7, 'subsample': 0.8441379425198781, 'colsample_bytree': 0.7416068335393717, 'min_child_weight': 6, 'gamma': 0.426927788245953, 'reg_alpha': 2.7842275307897504, 'reg_lambda': 2.8384795773914027}. Best is trial 8 with value: 0.9469046120458678.
# [I 2025-12-29 21:15:26,085] Trial 24 finished with value: 0.945852659880827 and parameters: {'n_estimators': 416, 'learning_rate': 0.010702057678469044, 'max_depth': 7, 'subsample': 0.8470338486894496, 'colsample_bytree': 0.7507920496069456, 'min_child_weight': 4, 'gamma': 0.4847630694034716, 'reg_alpha': 2.842190163932043, 'reg_lambda': 1.9994996957430906}. Best is trial 8 with value: 0.9469046120458678.
# [I 2025-12-29 21:15:28,818] Trial 25 finished with value: 0.9463273880396568 and parameters: {'n_estimators': 342, 'learning_rate': 0.030352945289106318, 'max_depth': 6, 'subsample': 0.8681074808937057, 'colsample_bytree': 0.8130958897070639, 'min_child_weight': 2, 'gamma': 0.49423089092224176, 'reg_alpha': 3.106745036335294, 'reg_lambda': 0.6969224778752706}. Best is trial 8 with value: 0.9469046120458678.
# [I 2025-12-29 21:15:31,440] Trial 26 finished with value: 0.9463142920904477 and parameters: {'n_estimators': 326, 'learning_rate': 0.03062896191061898, 'max_depth': 6, 'subsample': 0.8692861034171031, 'colsample_bytree': 0.8340234453577906, 'min_child_weight': 2, 'gamma': 0.7564401291525022, 'reg_alpha': 3.1880692662658308, 'reg_lambda': 2.7687598940665343}. Best is trial 8 with value: 0.9469046120458678.
# [I 2025-12-29 21:15:34,830] Trial 27 finished with value: 0.947543974994755 and parameters: {'n_estimators': 377, 'learning_rate': 0.015540509622028936, 'max_depth': 6, 'subsample': 0.7388243512971365, 'colsample_bytree': 0.8786612076050495, 'min_child_weight': 1, 'gamma': 0.5026426439897561, 'reg_alpha': 2.050621932811244, 'reg_lambda': 1.4631689536095855}. Best is trial 27 with value: 0.947543974994755.
# [I 2025-12-29 21:15:37,386] Trial 28 finished with value: 0.9457672021306308 and parameters: {'n_estimators': 292, 'learning_rate': 0.03649979607679272, 'max_depth': 6, 'subsample': 0.7339923756950965, 'colsample_bytree': 0.896663536292013, 'min_child_weight': 1, 'gamma': 0.7873666290857264, 'reg_alpha': 1.9611599028361646, 'reg_lambda': 0.021921505667978014}. Best is trial 27 with value: 0.947543974994755.
# [I 2025-12-29 21:15:39,858] Trial 29 finished with value: 0.9468104013908432 and parameters: {'n_estimators': 364, 'learning_rate': 0.016147928071135124, 'max_depth': 5, 'subsample': 0.6722549640617577, 'colsample_bytree': 0.8672688593131032, 'min_child_weight': 2, 'gamma': 0.5420446164294747, 'reg_alpha': 1.411817187684642, 'reg_lambda': 1.3817442179038744}. Best is trial 27 with value: 0.947543974994755.
# [I 2025-12-29 21:15:45,404] Trial 30 finished with value: 0.947564888423849 and parameters: {'n_estimators': 378, 'learning_rate': 0.0193729435330514, 'max_depth': 5, 'subsample': 0.6734926192846902, 'colsample_bytree': 0.861860720161199, 'min_child_weight': 1, 'gamma': 0.5881413560499081, 'reg_alpha': 1.4926481818307848, 'reg_lambda': 1.494361841634843}. Best is trial 30 with value: 0.947564888423849.
# [I 2025-12-29 21:15:47,344] Trial 31 finished with value: 0.9440201624164966 and parameters: {'n_estimators': 390, 'learning_rate': 0.09986801736309214, 'max_depth': 5, 'subsample': 0.6945160858429741, 'colsample_bytree': 0.8626571960966681, 'min_child_weight': 1, 'gamma': 0.6172089505435933, 'reg_alpha': 1.5564872461116743, 'reg_lambda': 1.642899315848211}. Best is trial 30 with value: 0.947564888423849.
# [I 2025-12-29 21:15:50,534] Trial 32 finished with value: 0.9471974000531855 and parameters: {'n_estimators': 368, 'learning_rate': 0.0175476728235211, 'max_depth': 5, 'subsample': 0.6636308090795907, 'colsample_bytree': 0.8693665635649375, 'min_child_weight': 2, 'gamma': 0.5489294753103199, 'reg_alpha': 1.2986190487188882, 'reg_lambda': 1.3180157252829123}. Best is trial 30 with value: 0.947564888423849.
# [I 2025-12-29 21:15:52,741] Trial 33 finished with value: 0.9453254142930259 and parameters: {'n_estimators': 413, 'learning_rate': 0.022286067243739723, 'max_depth': 4, 'subsample': 0.6431060727961317, 'colsample_bytree': 0.8960162518871506, 'min_child_weight': 1, 'gamma': 0.6024824514726824, 'reg_alpha': 2.1007375130596104, 'reg_lambda': 2.0880206092789972}. Best is trial 30 with value: 0.947564888423849.
# [I 2025-12-29 21:15:54,015] Trial 34 finished with value: 0.9448049839440991 and parameters: {'n_estimators': 147, 'learning_rate': 0.01787693886760989, 'max_depth': 5, 'subsample': 0.601358229717152, 'colsample_bytree': 0.8052996667003287, 'min_child_weight': 2, 'gamma': 0.6843700441048469, 'reg_alpha': 1.2218704303743628, 'reg_lambda': 1.3927312136229841}. Best is trial 30 with value: 0.947564888423849.
# [I 2025-12-29 21:15:57,796] Trial 35 finished with value: 0.9462833562512444 and parameters: {'n_estimators': 371, 'learning_rate': 0.023829576012901595, 'max_depth': 5, 'subsample': 0.6805280145439063, 'colsample_bytree': 0.8402628793695189, 'min_child_weight': 1, 'gamma': 0.7630290984399483, 'reg_alpha': 1.7359885558928347, 'reg_lambda': 0.6058716977914094}. Best is trial 30 with value: 0.947564888423849.
# [I 2025-12-29 21:15:59,227] Trial 36 finished with value: 0.947104726167711 and parameters: {'n_estimators': 308, 'learning_rate': 0.017825620476859875, 'max_depth': 4, 'subsample': 0.7088093448271039, 'colsample_bytree': 0.8648948335676014, 'min_child_weight': 2, 'gamma': 0.43251304726241135, 'reg_alpha': 0.5280795329337967, 'reg_lambda': 1.8631781445027031}. Best is trial 30 with value: 0.947564888423849.
# [I 2025-12-29 21:16:00,340] Trial 37 finished with value: 0.9486167069567552 and parameters: {'n_estimators': 291, 'learning_rate': 0.019656252733568216, 'max_depth': 3, 'subsample': 0.7449355997488212, 'colsample_bytree': 0.8687947530933255, 'min_child_weight': 3, 'gamma': 0.45485956436552216, 'reg_alpha': 0.5193107217488591, 'reg_lambda': 1.8272024338336184}. Best is trial 37 with value: 0.9486167069567552.
# [I 2025-12-29 21:16:01,116] Trial 38 finished with value: 0.94673256067233 and parameters: {'n_estimators': 225, 'learning_rate': 0.03618964601473406, 'max_depth': 3, 'subsample': 0.738092348319538, 'colsample_bytree': 0.8347786041555896, 'min_child_weight': 3, 'gamma': 0.5621283364714575, 'reg_alpha': 0.30737432405774934, 'reg_lambda': 2.3959362745179686}. Best is trial 37 with value: 0.9486167069567552.
# [I 2025-12-29 21:16:02,118] Trial 39 finished with value: 0.9453811388932319 and parameters: {'n_estimators': 274, 'learning_rate': 0.06883534520111771, 'max_depth': 3, 'subsample': 0.7704895629433074, 'colsample_bytree': 0.873555524423388, 'min_child_weight': 1, 'gamma': 0.6934822404555233, 'reg_alpha': 0.5324403091803007, 'reg_lambda': 1.6622329536737226}. Best is trial 37 with value: 0.9486167069567552.
# [I 2025-12-29 21:16:02,819] Trial 40 finished with value: 0.9439246822561914 and parameters: {'n_estimators': 195, 'learning_rate': 0.08630463687253202, 'max_depth': 3, 'subsample': 0.6264282289165846, 'colsample_bytree': 0.8022902948620741, 'min_child_weight': 4, 'gamma': 0.4771294678744432, 'reg_alpha': 1.0661717143942664, 'reg_lambda': 1.1869420883883546}. Best is trial 37 with value: 0.9486167069567552.
# [I 2025-12-29 21:16:04,398] Trial 41 finished with value: 0.9435829180714744 and parameters: {'n_estimators': 355, 'learning_rate': 0.04301973587702305, 'max_depth': 4, 'subsample': 0.5615768460411723, 'colsample_bytree': 0.8995311315085975, 'min_child_weight': 7, 'gamma': 0.3133171029914321, 'reg_alpha': 1.5639931099138256, 'reg_lambda': 1.9420309873396921}. Best is trial 37 with value: 0.9486167069567552.
# [I 2025-12-29 21:16:06,479] Trial 42 finished with value: 0.947518651705213 and parameters: {'n_estimators': 312, 'learning_rate': 0.020255364848496306, 'max_depth': 4, 'subsample': 0.7086968186719462, 'colsample_bytree': 0.8548297879639779, 'min_child_weight': 2, 'gamma': 0.4396069216035984, 'reg_alpha': 0.342637121662599, 'reg_lambda': 1.7719078931872358}. Best is trial 37 with value: 0.9486167069567552.
# [I 2025-12-29 21:16:07,768] Trial 43 finished with value: 0.9477948693278171 and parameters: {'n_estimators': 316, 'learning_rate': 0.020414502601607296, 'max_depth': 3, 'subsample': 0.6644259302496602, 'colsample_bytree': 0.8507239313460154, 'min_child_weight': 2, 'gamma': 0.6023370214544898, 'reg_alpha': 0.4121386883082784, 'reg_lambda': 1.577679222703297}. Best is trial 37 with value: 0.9486167069567552.
# [I 2025-12-29 21:16:08,925] Trial 44 finished with value: 0.9477127523809907 and parameters: {'n_estimators': 314, 'learning_rate': 0.02600722774576907, 'max_depth': 3, 'subsample': 0.7515697253564432, 'colsample_bytree': 0.8525178012393628, 'min_child_weight': 3, 'gamma': 0.6282055967037886, 'reg_alpha': 0.35875094559821735, 'reg_lambda': 1.5745070076951702}. Best is trial 37 with value: 0.9486167069567552.
# [I 2025-12-29 21:16:09,932] Trial 45 finished with value: 0.9476432636709016 and parameters: {'n_estimators': 274, 'learning_rate': 0.024557972670453322, 'max_depth': 3, 'subsample': 0.7487163744409786, 'colsample_bytree': 0.8236597342605487, 'min_child_weight': 3, 'gamma': 0.6467490547517276, 'reg_alpha': 0.15749836949211965, 'reg_lambda': 1.580738775288946}. Best is trial 37 with value: 0.9486167069567552.
# [I 2025-12-29 21:16:10,979] Trial 46 finished with value: 0.9477431536916544 and parameters: {'n_estimators': 273, 'learning_rate': 0.033131922118663656, 'max_depth': 3, 'subsample': 0.757759205539801, 'colsample_bytree': 0.8279715020683277, 'min_child_weight': 3, 'gamma': 0.8536903086167867, 'reg_alpha': 0.0800891539716923, 'reg_lambda': 2.0728674249926504}. Best is trial 37 with value: 0.9486167069567552.
# [I 2025-12-29 21:16:11,937] Trial 47 finished with value: 0.9478288118900527 and parameters: {'n_estimators': 273, 'learning_rate': 0.028440353545215062, 'max_depth': 3, 'subsample': 0.7556673084839868, 'colsample_bytree': 0.7842087865545618, 'min_child_weight': 5, 'gamma': 0.8197960265978097, 'reg_alpha': 0.10417548585966324, 'reg_lambda': 2.521338241607103}. Best is trial 37 with value: 0.9486167069567552.
# [I 2025-12-29 21:16:12,718] Trial 48 finished with value: 0.9467174602410993 and parameters: {'n_estimators': 210, 'learning_rate': 0.05074962232707646, 'max_depth': 3, 'subsample': 0.809016751953395, 'colsample_bytree': 0.7931024516366858, 'min_child_weight': 5, 'gamma': 0.8844329539057859, 'reg_alpha': 0.6807780547545264, 'reg_lambda': 2.601649556156828}. Best is trial 37 with value: 0.9486167069567552.
# [I 2025-12-29 21:16:13,484] Trial 49 finished with value: 0.9468530968579076 and parameters: {'n_estimators': 183, 'learning_rate': 0.03964463825435895, 'max_depth': 3, 'subsample': 0.7704120878184811, 'colsample_bytree': 0.8470610592273004, 'min_child_weight': 4, 'gamma': 0.8949411228720284, 'reg_alpha': 0.3549323912361506, 'reg_lambda': 3.3096790812694774}. Best is trial 37 with value: 0.9486167069567552.
# [I 2025-12-29 21:16:14,447] Trial 50 finished with value: 0.9467967040970275 and parameters: {'n_estimators': 248, 'learning_rate': 0.027457586464897342, 'max_depth': 3, 'subsample': 0.7951031009243532, 'colsample_bytree': 0.7777311413611749, 'min_child_weight': 7, 'gamma': 0.9559343892868262, 'reg_alpha': 0.013395524531201145, 'reg_lambda': 2.1755542597377335}. Best is trial 37 with value: 0.9486167069567552.
# [I 2025-12-29 21:16:15,399] Trial 51 finished with value: 0.9470928997237824 and parameters: {'n_estimators': 280, 'learning_rate': 0.031130367534735526, 'max_depth': 3, 'subsample': 0.7616295034235961, 'colsample_bytree': 0.7588395800595775, 'min_child_weight': 5, 'gamma': 0.8101747323728448, 'reg_alpha': 0.23727098928834384, 'reg_lambda': 3.0160387994148876}. Best is trial 37 with value: 0.9486167069567552.
# [I 2025-12-29 21:16:16,462] Trial 52 finished with value: 0.9478475872049904 and parameters: {'n_estimators': 286, 'learning_rate': 0.027790071767189124, 'max_depth': 3, 'subsample': 0.7485098359510893, 'colsample_bytree': 0.8241025803400042, 'min_child_weight': 3, 'gamma': 0.8354270413726717, 'reg_alpha': 0.15808035848938085, 'reg_lambda': 2.4602625653399084}. Best is trial 37 with value: 0.9486167069567552.
# [I 2025-12-29 21:16:20,406] Trial 53 finished with value: 0.947151764679156 and parameters: {'n_estimators': 258, 'learning_rate': 0.03413885172137987, 'max_depth': 3, 'subsample': 0.7817467131979132, 'colsample_bytree': 0.8262149714731558, 'min_child_weight': 3, 'gamma': 0.7139948663744015, 'reg_alpha': 0.5896969761196355, 'reg_lambda': 2.4402726318750343}. Best is trial 37 with value: 0.9486167069567552.
# [I 2025-12-29 21:16:21,649] Trial 54 finished with value: 0.9473392505642618 and parameters: {'n_estimators': 321, 'learning_rate': 0.027282252437865577, 'max_depth': 3, 'subsample': 0.7280249420923435, 'colsample_bytree': 0.8014771706436712, 'min_child_weight': 4, 'gamma': 0.8273468903650921, 'reg_alpha': 0.7609190076026795, 'reg_lambda': 2.7134809504172015}. Best is trial 37 with value: 0.9486167069567552.
# [I 2025-12-29 21:16:22,460] Trial 55 finished with value: 0.9473196066404481 and parameters: {'n_estimators': 230, 'learning_rate': 0.027059099691234482, 'max_depth': 3, 'subsample': 0.8200846319957604, 'colsample_bytree': 0.8455133339412069, 'min_child_weight': 3, 'gamma': 0.8564281653036376, 'reg_alpha': 1.064716811922548, 'reg_lambda': 2.290471191062812}. Best is trial 37 with value: 0.9486167069567552.
# [I 2025-12-29 21:16:23,404] Trial 56 finished with value: 0.9472423672665414 and parameters: {'n_estimators': 266, 'learning_rate': 0.039094518914757, 'max_depth': 3, 'subsample': 0.7536142028740399, 'colsample_bytree': 0.8136513361054742, 'min_child_weight': 4, 'gamma': 0.965376904633055, 'reg_alpha': 0.37669556816708155, 'reg_lambda': 3.8426953409053297}. Best is trial 37 with value: 0.9486167069567552.
# [I 2025-12-29 21:16:24,588] Trial 57 finished with value: 0.9467655009935549 and parameters: {'n_estimators': 340, 'learning_rate': 0.03302283265881911, 'max_depth': 3, 'subsample': 0.6945662824931902, 'colsample_bytree': 0.7881297753506775, 'min_child_weight': 8, 'gamma': 0.730821960363628, 'reg_alpha': 0.11950268437168676, 'reg_lambda': 2.1119371583626396}. Best is trial 37 with value: 0.9486167069567552.
# [I 2025-12-29 21:16:26,075] Trial 58 finished with value: 0.9471214970006268 and parameters: {'n_estimators': 297, 'learning_rate': 0.02474191347109138, 'max_depth': 4, 'subsample': 0.7222648766354131, 'colsample_bytree': 0.8858221196655623, 'min_child_weight': 3, 'gamma': 0.9313256694051527, 'reg_alpha': 1.0075942196395213, 'reg_lambda': 2.9272020073096097}. Best is trial 37 with value: 0.9486167069567552.
# [I 2025-12-29 21:16:27,297] Trial 59 finished with value: 0.9475237297263348 and parameters: {'n_estimators': 290, 'learning_rate': 0.02117684490490478, 'max_depth': 3, 'subsample': 0.7894320792944748, 'colsample_bytree': 0.8499206445237083, 'min_child_weight': 4, 'gamma': 0.8482399715333151, 'reg_alpha': 0.4352270347461009, 'reg_lambda': 3.1659574247660185}. Best is trial 37 with value: 0.9486167069567552.
# [I 2025-12-29 21:16:28,547] Trial 60 finished with value: 0.9466549204020189 and parameters: {'n_estimators': 310, 'learning_rate': 0.04817560556186243, 'max_depth': 3, 'subsample': 0.7467085727859667, 'colsample_bytree': 0.8295459277247778, 'min_child_weight': 5, 'gamma': 0.6343193972440783, 'reg_alpha': 0.7012949350303777, 'reg_lambda': 2.6173978119359895}. Best is trial 37 with value: 0.9486167069567552.
# [I 2025-12-29 21:16:29,644] Trial 61 finished with value: 0.9464841385337616 and parameters: {'n_estimators': 242, 'learning_rate': 0.04267761812150041, 'max_depth': 4, 'subsample': 0.7709079461358819, 'colsample_bytree': 0.7681313497000082, 'min_child_weight': 6, 'gamma': 0.7899628977264772, 'reg_alpha': 0.21904828208485871, 'reg_lambda': 1.824997384123999}. Best is trial 37 with value: 0.9486167069567552.
# [I 2025-12-29 21:16:31,076] Trial 62 finished with value: 0.9478402374375771 and parameters: {'n_estimators': 276, 'learning_rate': 0.014338782903535753, 'max_depth': 3, 'subsample': 0.7527899147937882, 'colsample_bytree': 0.8206337164457016, 'min_child_weight': 3, 'gamma': 0.7282820862193875, 'reg_alpha': 0.010000595162284992, 'reg_lambda': 1.066958688555351}. Best is trial 37 with value: 0.9486167069567552.
# [I 2025-12-29 21:16:32,265] Trial 63 finished with value: 0.9474406105384974 and parameters: {'n_estimators': 333, 'learning_rate': 0.014001503351917738, 'max_depth': 3, 'subsample': 0.7616574336646308, 'colsample_bytree': 0.7010952004535447, 'min_child_weight': 3, 'gamma': 0.7323601419241232, 'reg_alpha': 0.03405748394778197, 'reg_lambda': 1.0183519455998615}. Best is trial 37 with value: 0.9486167069567552.
# [I 2025-12-29 21:16:33,369] Trial 64 finished with value: 0.9481915229118977 and parameters: {'n_estimators': 292, 'learning_rate': 0.010283477399656656, 'max_depth': 3, 'subsample': 0.7231141833151195, 'colsample_bytree': 0.817377629756126, 'min_child_weight': 3, 'gamma': 0.662390091469474, 'reg_alpha': 0.48935171957500573, 'reg_lambda': 2.0357793570948712}. Best is trial 37 with value: 0.9486167069567552.
# [I 2025-12-29 21:16:34,655] Trial 65 finished with value: 0.9475271039377382 and parameters: {'n_estimators': 290, 'learning_rate': 0.01013808110152509, 'max_depth': 3, 'subsample': 0.7185891525144252, 'colsample_bytree': 0.8213986862363941, 'min_child_weight': 2, 'gamma': 0.6606350792629385, 'reg_alpha': 0.5181371509250189, 'reg_lambda': 2.4687404845050134}. Best is trial 37 with value: 0.9486167069567552.
# [I 2025-12-29 21:16:35,548] Trial 66 finished with value: 0.9467685077165875 and parameters: {'n_estimators': 238, 'learning_rate': 0.013770122112071305, 'max_depth': 3, 'subsample': 0.7052635492804676, 'colsample_bytree': 0.793550902656659, 'min_child_weight': 4, 'gamma': 0.7692919865545819, 'reg_alpha': 3.6857858153197247, 'reg_lambda': 2.0066003388265767}. Best is trial 37 with value: 0.9486167069567552.
# [I 2025-12-29 21:16:36,621] Trial 67 finished with value: 0.9477236433999756 and parameters: {'n_estimators': 267, 'learning_rate': 0.014535944254563107, 'max_depth': 3, 'subsample': 0.654935647065254, 'colsample_bytree': 0.8130575309386568, 'min_child_weight': 3, 'gamma': 0.8374389495192405, 'reg_alpha': 0.003950485624737848, 'reg_lambda': 2.2759268897056173}. Best is trial 37 with value: 0.9486167069567552.
# [I 2025-12-29 21:16:38,708] Trial 68 finished with value: 0.9475684964914883 and parameters: {'n_estimators': 202, 'learning_rate': 0.021914185612075084, 'max_depth': 4, 'subsample': 0.6849771905522868, 'colsample_bytree': 0.6351843736882963, 'min_child_weight': 2, 'gamma': 0.8711836640566999, 'reg_alpha': 0.18621570068517382, 'reg_lambda': 1.0869435718128182}. Best is trial 37 with value: 0.9486167069567552.
# [I 2025-12-29 21:16:39,601] Trial 69 finished with value: 0.9474593190373675 and parameters: {'n_estimators': 256, 'learning_rate': 0.02955429486494377, 'max_depth': 3, 'subsample': 0.7329531588612167, 'colsample_bytree': 0.7374439575965382, 'min_child_weight': 3, 'gamma': 0.9341904150135483, 'reg_alpha': 0.9078623678383833, 'reg_lambda': 1.7866334666338832}. Best is trial 37 with value: 0.9486167069567552.
# [I 2025-12-29 21:16:40,263] Trial 70 finished with value: 0.9474842080224715 and parameters: {'n_estimators': 160, 'learning_rate': 0.01334545106207493, 'max_depth': 3, 'subsample': 0.739153959488163, 'colsample_bytree': 0.8844043282582285, 'min_child_weight': 4, 'gamma': 0.5761684603741791, 'reg_alpha': 0.6397252709377086, 'reg_lambda': 0.8987199334022562}. Best is trial 37 with value: 0.9486167069567552.
# [I 2025-12-29 21:16:41,446] Trial 71 finished with value: 0.9479367866549605 and parameters: {'n_estimators': 346, 'learning_rate': 0.020837243536851763, 'max_depth': 3, 'subsample': 0.7825656585026324, 'colsample_bytree': 0.8401123762597309, 'min_child_weight': 5, 'gamma': 0.8055951341618115, 'reg_alpha': 0.17486890099111305, 'reg_lambda': 0.483389411846076}. Best is trial 37 with value: 0.9486167069567552.
# [I 2025-12-29 21:16:42,488] Trial 72 finished with value: 0.9488309860848858 and parameters: {'n_estimators': 302, 'learning_rate': 0.020242010513768928, 'max_depth': 3, 'subsample': 0.7675689056452072, 'colsample_bytree': 0.8354882342816606, 'min_child_weight': 5, 'gamma': 0.8030793686304801, 'reg_alpha': 0.1934369244350881, 'reg_lambda': 0.0035177431210048904}. Best is trial 72 with value: 0.9488309860848858.
# [I 2025-12-29 21:16:43,674] Trial 73 finished with value: 0.9483817816638002 and parameters: {'n_estimators': 345, 'learning_rate': 0.020198163257793732, 'max_depth': 3, 'subsample': 0.8100911936133098, 'colsample_bytree': 0.8363051828007355, 'min_child_weight': 5, 'gamma': 0.8130422131809821, 'reg_alpha': 0.43582900577950756, 'reg_lambda': 0.026123887672770945}. Best is trial 72 with value: 0.9488309860848858.
# [I 2025-12-29 21:16:44,919] Trial 74 finished with value: 0.9479889700035947 and parameters: {'n_estimators': 344, 'learning_rate': 0.015684151946862315, 'max_depth': 3, 'subsample': 0.8112477828651299, 'colsample_bytree': 0.8073876343605311, 'min_child_weight': 6, 'gamma': 0.7926250610468607, 'reg_alpha': 0.8031550148975228, 'reg_lambda': 0.01893988063641533}. Best is trial 72 with value: 0.9488309860848858.
# [I 2025-12-29 21:16:46,092] Trial 75 finished with value: 0.9478943584521657 and parameters: {'n_estimators': 342, 'learning_rate': 0.016258117452310802, 'max_depth': 3, 'subsample': 0.8310997655780827, 'colsample_bytree': 0.839030246652748, 'min_child_weight': 6, 'gamma': 0.7930678033622529, 'reg_alpha': 0.7772976042573725, 'reg_lambda': 0.11299322913300236}. Best is trial 72 with value: 0.9488309860848858.
# [I 2025-12-29 21:16:47,284] Trial 76 finished with value: 0.9479029777248595 and parameters: {'n_estimators': 349, 'learning_rate': 0.011681765299705597, 'max_depth': 3, 'subsample': 0.8326393901530701, 'colsample_bytree': 0.8362862867252889, 'min_child_weight': 6, 'gamma': 0.791946068666679, 'reg_alpha': 0.8216978785808405, 'reg_lambda': 0.0057118824403984535}. Best is trial 72 with value: 0.9488309860848858.
# [I 2025-12-29 21:16:48,968] Trial 77 finished with value: 0.9481066330982744 and parameters: {'n_estimators': 352, 'learning_rate': 0.01644566592153097, 'max_depth': 4, 'subsample': 0.8316470423236647, 'colsample_bytree': 0.8388072597544101, 'min_child_weight': 6, 'gamma': 0.7924547568722259, 'reg_alpha': 0.8614541648354118, 'reg_lambda': 0.02891287216369194}. Best is trial 72 with value: 0.9488309860848858.
# [I 2025-12-29 21:16:50,754] Trial 78 finished with value: 0.9480344717454896 and parameters: {'n_estimators': 400, 'learning_rate': 0.011497175644628009, 'max_depth': 4, 'subsample': 0.8632285474364122, 'colsample_bytree': 0.8609687012877002, 'min_child_weight': 7, 'gamma': 0.755194792886499, 'reg_alpha': 1.1861832687576357, 'reg_lambda': 0.2478204554845156}. Best is trial 72 with value: 0.9488309860848858.
# [I 2025-12-29 21:16:55,326] Trial 79 finished with value: 0.9473967791982874 and parameters: {'n_estimators': 399, 'learning_rate': 0.01868638205984735, 'max_depth': 4, 'subsample': 0.8965340841126367, 'colsample_bytree': 0.878474069452946, 'min_child_weight': 7, 'gamma': 0.7498158208428156, 'reg_alpha': 1.2371717144128522, 'reg_lambda': 0.2123622162306184}. Best is trial 72 with value: 0.9488309860848858.
# [I 2025-12-29 21:16:57,199] Trial 80 finished with value: 0.9475125714430801 and parameters: {'n_estimators': 359, 'learning_rate': 0.01652693426149591, 'max_depth': 4, 'subsample': 0.8605294027404812, 'colsample_bytree': 0.8596959186437565, 'min_child_weight': 7, 'gamma': 0.6792053973794646, 'reg_alpha': 1.057283977793654, 'reg_lambda': 0.4811647694815994}. Best is trial 72 with value: 0.9488309860848858.
# [I 2025-12-29 21:16:59,217] Trial 81 finished with value: 0.9475966260558609 and parameters: {'n_estimators': 427, 'learning_rate': 0.019702033715501503, 'max_depth': 4, 'subsample': 0.8119613921174594, 'colsample_bytree': 0.8901585009754671, 'min_child_weight': 8, 'gamma': 0.9158278509572546, 'reg_alpha': 0.4795846396123129, 'reg_lambda': 0.268876343648991}. Best is trial 72 with value: 0.9488309860848858.
# [I 2025-12-29 21:17:00,629] Trial 82 finished with value: 0.9479901726928078 and parameters: {'n_estimators': 395, 'learning_rate': 0.011628471312097278, 'max_depth': 3, 'subsample': 0.8572562861435936, 'colsample_bytree': 0.8374200153586387, 'min_child_weight': 6, 'gamma': 0.7032817909929291, 'reg_alpha': 0.6145276378165386, 'reg_lambda': 0.00717248913832599}. Best is trial 72 with value: 0.9488309860848858.
# [I 2025-12-29 21:17:02,145] Trial 83 finished with value: 0.947243503139687 and parameters: {'n_estimators': 389, 'learning_rate': 0.010208184806589853, 'max_depth': 3, 'subsample': 0.8499756716784047, 'colsample_bytree': 0.8698122758756243, 'min_child_weight': 6, 'gamma': 0.7067011468166742, 'reg_alpha': 0.9374267789038173, 'reg_lambda': 0.16472290823147653}. Best is trial 72 with value: 0.9488309860848858.
# [I 2025-12-29 21:17:03,922] Trial 84 finished with value: 0.9480084802952735 and parameters: {'n_estimators': 402, 'learning_rate': 0.01201335225765881, 'max_depth': 4, 'subsample': 0.8706258958988169, 'colsample_bytree': 0.8092169594327202, 'min_child_weight': 5, 'gamma': 0.7569054806924523, 'reg_alpha': 0.6265216963283039, 'reg_lambda': 0.42728388690532304}. Best is trial 72 with value: 0.9488309860848858.
# [I 2025-12-29 21:17:05,892] Trial 85 finished with value: 0.9471162185313027 and parameters: {'n_estimators': 442, 'learning_rate': 0.01248979578623647, 'max_depth': 4, 'subsample': 0.8805134588112163, 'colsample_bytree': 0.8062115913561677, 'min_child_weight': 6, 'gamma': 0.7589518908263478, 'reg_alpha': 1.1702018128519507, 'reg_lambda': 0.35818420239591114}. Best is trial 72 with value: 0.9488309860848858.
# [I 2025-12-29 21:17:07,768] Trial 86 finished with value: 0.9474175589952468 and parameters: {'n_estimators': 404, 'learning_rate': 0.01604189668427737, 'max_depth': 4, 'subsample': 0.8614857661125997, 'colsample_bytree': 0.8582495355428319, 'min_child_weight': 6, 'gamma': 0.7748864663403026, 'reg_alpha': 0.6903039037675427, 'reg_lambda': 0.7433052608191137}. Best is trial 72 with value: 0.9488309860848858.
# [I 2025-12-29 21:17:09,892] Trial 87 finished with value: 0.9475389637897005 and parameters: {'n_estimators': 427, 'learning_rate': 0.010106107791789774, 'max_depth': 4, 'subsample': 0.8370172110840693, 'colsample_bytree': 0.8072448422756695, 'min_child_weight': 5, 'gamma': 0.6599090333895783, 'reg_alpha': 0.6172930258293529, 'reg_lambda': 0.5626673462198045}. Best is trial 72 with value: 0.9488309860848858.
# [I 2025-12-29 21:17:11,976] Trial 88 finished with value: 0.9479314413695692 and parameters: {'n_estimators': 467, 'learning_rate': 0.012423030966336053, 'max_depth': 4, 'subsample': 0.8810672771807321, 'colsample_bytree': 0.8426717396222703, 'min_child_weight': 7, 'gamma': 0.7425400783383275, 'reg_alpha': 1.4242877552708966, 'reg_lambda': 0.0839717495775634}. Best is trial 72 with value: 0.9488309860848858.
# [I 2025-12-29 21:17:13,697] Trial 89 finished with value: 0.948425746636145 and parameters: {'n_estimators': 376, 'learning_rate': 0.0229944600611697, 'max_depth': 4, 'subsample': 0.8187703770036634, 'colsample_bytree': 0.7961166930155079, 'min_child_weight': 6, 'gamma': 0.5126897033962097, 'reg_alpha': 0.8793072025526787, 'reg_lambda': 0.375633712398408}. Best is trial 72 with value: 0.9488309860848858.
# [I 2025-12-29 21:17:16,711] Trial 90 finished with value: 0.9476903021823464 and parameters: {'n_estimators': 383, 'learning_rate': 0.018746815377806755, 'max_depth': 4, 'subsample': 0.8612041147232583, 'colsample_bytree': 0.8726066813960629, 'min_child_weight': 8, 'gamma': 0.5172527159167556, 'reg_alpha': 0.9331213480041447, 'reg_lambda': 0.2967849995702011}. Best is trial 72 with value: 0.9488309860848858.
# [I 2025-12-29 21:17:18,294] Trial 91 finished with value: 0.945107861177593 and parameters: {'n_estimators': 369, 'learning_rate': 0.060724743930939296, 'max_depth': 4, 'subsample': 0.8514203014462091, 'colsample_bytree': 0.8327425854755218, 'min_child_weight': 5, 'gamma': 0.4017877563755902, 'reg_alpha': 1.1225728513878255, 'reg_lambda': 0.4292336851036416}. Best is trial 72 with value: 0.9488309860848858.
# [I 2025-12-29 21:17:20,306] Trial 92 finished with value: 0.9468252345578045 and parameters: {'n_estimators': 396, 'learning_rate': 0.023250128411270908, 'max_depth': 4, 'subsample': 0.8241421892498572, 'colsample_bytree': 0.7938365969232908, 'min_child_weight': 6, 'gamma': 0.46072233888074193, 'reg_alpha': 4.589780106496999, 'reg_lambda': 0.005706854081353095}. Best is trial 72 with value: 0.9488309860848858.
# [I 2025-12-29 21:17:22,547] Trial 93 finished with value: 0.9483809798709917 and parameters: {'n_estimators': 328, 'learning_rate': 0.01590402666530119, 'max_depth': 4, 'subsample': 0.815778151988209, 'colsample_bytree': 0.8159857382138574, 'min_child_weight': 7, 'gamma': 0.7067758662134113, 'reg_alpha': 0.5384440310661036, 'reg_lambda': 0.20355739506712525}. Best is trial 72 with value: 0.9488309860848858.
# [I 2025-12-29 21:17:23,854] Trial 94 finished with value: 0.9479050490229486 and parameters: {'n_estimators': 301, 'learning_rate': 0.01769432216696841, 'max_depth': 4, 'subsample': 0.8734449647494177, 'colsample_bytree': 0.8523411329350989, 'min_child_weight': 7, 'gamma': 0.8700949979808933, 'reg_alpha': 0.514489613026336, 'reg_lambda': 0.647100216100462}. Best is trial 72 with value: 0.9488309860848858.
# [I 2025-12-29 21:17:25,445] Trial 95 finished with value: 0.9473368451858356 and parameters: {'n_estimators': 329, 'learning_rate': 0.011720920648208151, 'max_depth': 4, 'subsample': 0.8014455598103908, 'colsample_bytree': 0.814365166557811, 'min_child_weight': 7, 'gamma': 0.3591999018329255, 'reg_alpha': 0.29895223980404706, 'reg_lambda': 0.2035311021635829}. Best is trial 72 with value: 0.9488309860848858.
# [I 2025-12-29 21:17:27,210] Trial 96 finished with value: 0.9416246059522425 and parameters: {'n_estimators': 364, 'learning_rate': 0.08114740984133102, 'max_depth': 5, 'subsample': 0.8408129116979431, 'colsample_bytree': 0.7717596291540108, 'min_child_weight': 8, 'gamma': 0.6931486853806695, 'reg_alpha': 0.6174621745391631, 'reg_lambda': 0.37124640204320175}. Best is trial 72 with value: 0.9488309860848858.
# [I 2025-12-29 21:17:32,355] Trial 97 finished with value: 0.9472986263952865 and parameters: {'n_estimators': 427, 'learning_rate': 0.024882178170761306, 'max_depth': 4, 'subsample': 0.892608647650869, 'colsample_bytree': 0.8629777240667309, 'min_child_weight': 5, 'gamma': 0.7101075578013069, 'reg_alpha': 0.4396300617068477, 'reg_lambda': 0.1555572346284912}. Best is trial 72 with value: 0.9488309860848858.
# [I 2025-12-29 21:17:33,923] Trial 98 finished with value: 0.9477893904102908 and parameters: {'n_estimators': 323, 'learning_rate': 0.014580303160494176, 'max_depth': 4, 'subsample': 0.7915107695701713, 'colsample_bytree': 0.7976458856875288, 'min_child_weight': 9, 'gamma': 0.2831858881150777, 'reg_alpha': 0.2677509893782803, 'reg_lambda': 0.5201913637581917}. Best is trial 72 with value: 0.9488309860848858.
# [I 2025-12-29 21:17:35,917] Trial 99 finished with value: 0.9465985276411389 and parameters: {'n_estimators': 380, 'learning_rate': 0.022308686207154326, 'max_depth': 5, 'subsample': 0.8205993055536112, 'colsample_bytree': 0.7820354181475276, 'min_child_weight': 7, 'gamma': 0.6812342277581882, 'reg_alpha': 1.329766655278761, 'reg_lambda': 0.7235978600134485}. Best is trial 72 with value: 0.9488309860848858.
# [I 2025-12-29 21:17:38,151] Trial 100 finished with value: 0.9478906167523917 and parameters: {'n_estimators': 412, 'learning_rate': 0.019437980545213347, 'max_depth': 4, 'subsample': 0.8578017384151203, 'colsample_bytree': 0.7634385503589125, 'min_child_weight': 6, 'gamma': 0.718085302489774, 'reg_alpha': 0.7190288446426479, 'reg_lambda': 0.254104667516494}. Best is trial 72 with value: 0.9488309860848858.

# %%
best_params = study.best_params
best_params.update({
    "random_state": 42,
    "n_jobs": -1,
    "scale_pos_weight": scale_pos_weight,
    "eval_metric": "logloss"
})

xgb = XGBClassifier(**best_params)
pipe_xgb = make_pipeline(preprocessor, xgb)

# %%
start_train = time.time()
pipe_xgb.fit(X_train, y_train)
train_time = time.time() - start_train
print(f"⏱ Training time: {train_time:.2f} seconds")
# Out:
# ⏱ Training time: 0.28 seconds

# %%
y_pred_train_xgb = pipe_xgb.predict_proba(X_train)[:, 1]
y_pred_test_xgb = pipe_xgb.predict_proba(X_test)[:, 1]
print(f"Training roc-auc score: {metrics.roc_auc_score(y_train, y_pred_train_xgb)}")
print(f"Testing roc-auc score: {metrics.roc_auc_score(y_test, y_pred_test_xgb)}")
# Out:
# Training roc-auc score: 0.9796886715785975
# Testing roc-auc score: 0.9568743920435842

# %%
print(metrics.classification_report(y_test, pipe_xgb.predict(X_test)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      0.91      0.95      1619
#            1       0.50      0.86      0.63       167
#
#     accuracy                           0.91      1786
#    macro avg       0.74      0.89      0.79      1786
# weighted avg       0.94      0.91      0.92      1786

# %% [markdown]
# The model is not overfitting much and it capturing almost 86% fraudsters.

# %% [markdown]
# ### Testing Pipeline

# %%
test_beneficiary = pd.read_csv("../data/Test_Beneficiarydata-1542969243754.csv")
test_inpatient = pd.read_csv("../data/Test_Inpatientdata-1542969243754.csv")
test_outpatient = pd.read_csv("../data/Test_Outpatientdata-1542969243754.csv")
test_providers = pd.read_csv("../data/Test-1542969243754.csv")

# %%
top_diagnosis_code = pd.read_csv('../data/processed/top_diagnosis_code.csv')
top_attending_physician = pd.read_csv('../data/processed/top_attending_physician.csv')
top_operating_physician = pd.read_csv('../data/processed/top_operating_physician.csv')

# %%
test_beneficiary.loc[:, test_beneficiary.columns.str.contains('ChronicCond_')] = \
test_beneficiary.filter(like='ChronicCond_').replace({1: 1, 2: 0})
test_beneficiary = pd.concat([test_beneficiary,
 pd.get_dummies(test_beneficiary['Gender'].map({1: 'Male', 2: 'Female'}), prefix='Gender'),
 pd.get_dummies(test_beneficiary['Race'].map({1: 'White', 2: 'Black', 3: 'Other', 4: 'Unknown', 5: 'Hispanic'}), prefix='Race')], axis=1)
test_beneficiary['RenalDiseaseIndicator'] = test_beneficiary['RenalDiseaseIndicator'].map({'0':0,'Y':1})

# %%
test_inpatient['Is_Inpatient'] = True
test_inpatient.head()
# Out:
#       BeneID   ClaimID ClaimStartDt  ClaimEndDt  Provider  \
# 0  BENE11014  CLM67387   2009-09-09  2009-09-16  PRV57070
# 1  BENE11017  CLM31237   2008-12-25  2009-01-08  PRV54750
# 2  BENE11026  CLM78930   2009-12-09  2009-12-13  PRV53758
# 3  BENE11031  CLM56810   2009-06-23  2009-07-06  PRV55825
# 4  BENE11085  CLM34625   2009-01-20  2009-01-31  PRV52338
#
#    InscClaimAmtReimbursed AttendingPhysician OperatingPhysician  \
# 0                    9000          PHY317786          PHY427017
# 1                   14000          PHY314656          PHY426644
# 2                    2000          PHY349495                NaN
# 3                   16000          PHY429538          PHY371893
# 4                   19000          PHY397161                NaN
#
#   OtherPhysician AdmissionDt ClmAdmitDiagnosisCode  DeductibleAmtPaid  \
# 0            NaN  2009-09-09                  5789             1068.0
# 1            NaN  2008-12-25                  5939             1068.0
# 2            NaN  2009-12-09                  4019             1068.0
# 3            NaN  2009-06-23                  8208             1068.0
# 4            NaN  2009-01-20                  4279             1068.0
#
#   DischargeDt DiagnosisGroupCode ClmDiagnosisCode_1 ClmDiagnosisCode_2  \
# 0  2009-09-16                332               5780               5533
# 1  2009-01-08                661               1889              41071
# 2  2009-12-13                241               4010              78791
# 3  2009-07-06                564               8208               4168
# 4  2009-01-31                880              29654               V142
#
#   ClmDiagnosisCode_3 ClmDiagnosisCode_4 ClmDiagnosisCode_5 ClmDiagnosisCode_6  \
# 0                496               V420              40390               2851
# 1               5990               5601               4588               5845
# 2              60000              41401              V1254               4372
# 3                920               5990              40391               2859
# 4              78702              30503               V140              V4582
#
#   ClmDiagnosisCode_7 ClmDiagnosisCode_8 ClmDiagnosisCode_9  \
# 0               5990                570              41071
# 1               4549              29570              34831
# 2              78650               7813               4254
# 3               4254              41400               5849
# 4              V6109               7242                NaN
#
#   ClmDiagnosisCode_10  ClmProcedureCode_1  ClmProcedureCode_2  \
# 0                4280              4443.0              5849.0
# 1                 NaN              5551.0                 NaN
# 2                 NaN                 NaN                 NaN
# 3               41401              8152.0              3320.0
# 4                 NaN                 NaN                 NaN
#
#    ClmProcedureCode_3  ClmProcedureCode_4  ClmProcedureCode_5  \
# 0                 NaN                 NaN                 NaN
# 1                 NaN                 NaN                 NaN
# 2                 NaN                 NaN                 NaN
# 3                 NaN                 NaN                 NaN
# 4                 NaN                 NaN                 NaN
#
#    ClmProcedureCode_6  Is_Inpatient
# 0                 NaN          True
# 1                 NaN          True
# 2                 NaN          True
# 3                 NaN          True
# 4                 NaN          True

# %%
test_outpatient['Is_Outpatient'] = True
test_outpatient.head()
# Out:
#       BeneID    ClaimID ClaimStartDt  ClaimEndDt  Provider  \
# 0  BENE11001  CLM392397   2009-06-02  2009-06-02  PRV55962
# 1  BENE11001  CLM430760   2009-06-23  2009-06-23  PRV56112
# 2  BENE11007  CLM233081   2009-03-07  2009-03-07  PRV56979
# 3  BENE11007  CLM496381   2009-07-29  2009-07-29  PRV56573
# 4  BENE11007  CLM521391   2009-08-12  2009-08-12  PRV56573
#
#    InscClaimAmtReimbursed AttendingPhysician OperatingPhysician  \
# 0                      30          PHY347633                NaN
# 1                      30          PHY381777                NaN
# 2                     200          PHY425311                NaN
# 3                      10          PHY393253          PHY347995
# 4                      10          PHY417685                NaN
#
#   OtherPhysician ClmDiagnosisCode_1 ClmDiagnosisCode_2 ClmDiagnosisCode_3  \
# 0      PHY347633              V5832              V5861               2724
# 1      PHY381777               9594              E9174               4019
# 2      PHY425311               7248                NaN                NaN
# 3            NaN              58889               2449                NaN
# 4      PHY382041               V666                NaN                NaN
#
#   ClmDiagnosisCode_4 ClmDiagnosisCode_5 ClmDiagnosisCode_6 ClmDiagnosisCode_7  \
# 0               3182              V5869              42731                NaN
# 1                NaN                NaN                NaN                NaN
# 2                NaN                NaN                NaN                NaN
# 3                NaN                NaN                NaN                NaN
# 4                NaN                NaN                NaN                NaN
#
#   ClmDiagnosisCode_8 ClmDiagnosisCode_9 ClmDiagnosisCode_10  \
# 0                NaN                NaN                 NaN
# 1                NaN                NaN                 NaN
# 2                NaN                NaN                 NaN
# 3                NaN                NaN                 NaN
# 4                NaN                NaN                 NaN
#
#    ClmProcedureCode_1  ClmProcedureCode_2  ClmProcedureCode_3  \
# 0                 NaN                 NaN                 NaN
# 1                 NaN                 NaN                 NaN
# 2                 NaN                 NaN                 NaN
# 3                 NaN                 NaN                 NaN
# 4                 NaN                 NaN                 NaN
#
#    ClmProcedureCode_4  ClmProcedureCode_5  ClmProcedureCode_6  \
# 0                 NaN                 NaN                 NaN
# 1                 NaN                 NaN                 NaN
# 2                 NaN                 NaN                 NaN
# 3                 NaN                 NaN                 NaN
# 4                 NaN                 NaN                 NaN
#
#    DeductibleAmtPaid ClmAdmitDiagnosisCode  Is_Outpatient
# 0                  0                   NaN           True
# 1                  0                   NaN           True
# 2                  0                   NaN           True
# 3                  0                  5939           True
# 4                  0                   NaN           True

# %%
test_patient_data = pd.concat([test_inpatient, test_outpatient])

# %%
for i in ['ClaimStartDt','ClaimEndDt','AdmissionDt','DischargeDt']:
    test_patient_data[i] = pd.to_datetime(test_patient_data[i])

# %%
test_patient_data['billing_before_admission'] = (test_patient_data['ClaimStartDt'] - test_patient_data['AdmissionDt']).dt.days < 0            
test_patient_data['billing_after_discharge'] = (test_patient_data['ClaimEndDt'] - test_patient_data['DischargeDt']).dt.days > 0

# %%
test_patient_data['top_diagnosis_code'] = np.where(test_patient_data['ClmAdmitDiagnosisCode'].isin(top_diagnosis_code['ClmAdmitDiagnosisCode']),1,0)

# %%
test_patient_data['hospital_stay_days'] = (test_patient_data['DischargeDt'] - test_patient_data['AdmissionDt']).dt.days + 1
test_patient_data['num_diagnoses'] =test_patient_data.filter(like='ClmDiagnosisCode_').notna().sum(axis=1)
test_patient_data['num_procedures'] =test_patient_data.filter(like='ClmProcedureCode_').notna().sum(axis=1)

# %%
test_patient_data['claim_duration_days'] = (test_patient_data['ClaimEndDt'] - test_patient_data['ClaimStartDt']).dt.days + 1
test_patient_data['num_of_physicians'] = test_patient_data.filter(like='Physician').notna().sum(axis=1)

# Binary columns
test_patient_data['is_top20_attending'] = test_patient_data['AttendingPhysician'].isin(top_attending_physician['AttendingPhysician']).astype(int)
test_patient_data['is_top20_operating'] = test_patient_data['OperatingPhysician'].isin(top_operating_physician['OperatingPhysician']).astype(int)
test_patient_data['stay_vs_claim_diff'] = test_patient_data['hospital_stay_days'] - test_patient_data['claim_duration_days']

# %%
test_patient_data = test_patient_data.merge(test_beneficiary,on='BeneID',how='left')
test_patient_data['DOB'] = pd.to_datetime(test_patient_data['DOB'])
test_patient_data['Age_at_Claim'] = ((pd.to_datetime(test_patient_data['ClaimStartDt']) - pd.to_datetime(test_patient_data['DOB'])).dt.days / 365.25).astype(int)

# %%
test_patient_data['Is_Dead'] = np.where(test_patient_data['DOD'].isna(), False, True)

# %%
for i in ['hospital_stay_days','stay_vs_claim_diff']:
    test_patient_data[i] = test_patient_data[i].fillna(0)
for i in ['Is_Inpatient','Is_Outpatient']:
    test_patient_data[i] = test_patient_data[i].fillna(False)

# %%
test_df = test_patient_data.groupby(['Provider']).agg(
    count_unique_beneficiary = ('BeneID','nunique'),
    count_unique_claims = ('ClaimID','count'),
    count_dead_beneficiary = ('Is_Dead','sum'),
    count_unique_states = ('State','nunique'),
    count_unique_counties = ('County','nunique'),
    mean_hospital_stay_days = ('hospital_stay_days', 'mean'),
    max_hospital_stay_days = ('hospital_stay_days', 'max'),
    total_top_diagnosis_codes = ('top_diagnosis_code','sum'),
    mean_total_diagnosis =('num_diagnoses','mean'),
    mean_total_procedures = ('num_procedures','mean'),
    mean_number_of_physicians = ('num_of_physicians','mean'),
    mean_difference_stay_vs_claim = ('stay_vs_claim_diff','mean'),
    patients_under_top_attending_physician = ('is_top20_attending','sum'),
    patients_under_top_operating_physician = ('is_top20_operating','sum'),
    mean_claim_amount = ('InscClaimAmtReimbursed','mean'),
    total_claim_amount = ('InscClaimAmtReimbursed','sum'),
    std_claim_amount = ('InscClaimAmtReimbursed','std'),
    mean_age = ('Age_at_Claim','mean'),
    count_of_males = ('Gender_Male','sum'),
    count_of_females = ('Gender_Female','sum'),
    count_of_black_people = ('Race_Black','sum'),
    count_of_white_people = ('Race_White','sum'),
    count_of_hispanic_people = ('Race_Hispanic','sum'),
    count_of_other_people = ('Race_Other','sum'),
    count_alzheimer = ('ChronicCond_Alzheimer', 'sum'),
    count_heartfailure = ('ChronicCond_Heartfailure', 'sum'),
    count_kidneydisease = ('ChronicCond_KidneyDisease', 'sum'),
    count_cancer = ('ChronicCond_Cancer', 'sum'),
    count_obstrpulmonary = ('ChronicCond_ObstrPulmonary', 'sum'),
    count_depression = ('ChronicCond_Depression', 'sum'),
    count_diabetes = ('ChronicCond_Diabetes', 'sum'),
    count_ischemicheart = ('ChronicCond_IschemicHeart', 'sum'),
    count_osteoporasis = ('ChronicCond_Osteoporasis', 'sum'),
    count_rheumatoidarthritis = ('ChronicCond_rheumatoidarthritis', 'sum'),
    count_stroke = ('ChronicCond_stroke', 'sum'), 
    count_renal_disease = ('RenalDiseaseIndicator', 'sum'),   
    mean_annual_inpatient_reimbursement = ('IPAnnualReimbursementAmt','mean'),
    mean_annual_inpatient_deductible = ('IPAnnualDeductibleAmt','mean'),
    mean_annual_outpatient_reimbursement = ('OPAnnualReimbursementAmt','mean'),
    mean_annual_outpatient_deductible = ('OPAnnualDeductibleAmt','mean'),
    count_inpatient = ('Is_Inpatient','sum'),
    count_outpatient = ('Is_Outpatient','sum')
).reset_index()

# %%
test_df['claims_per_bene'] = test_df['count_unique_claims'] / test_df['count_unique_beneficiary']

# %%
test_df = test_providers.merge(test_df, on="Provider", how="left")

# %%
test_df.head()
# Out:
#    Provider  count_unique_beneficiary  count_unique_claims  \
# 0  PRV51002                       169                  205
# 1  PRV51006                        81                  102
# 2  PRV51009                        30                   39
# 3  PRV51010                        25                   38
# 4  PRV51018                       146                  190
#
#    count_dead_beneficiary  count_unique_states  count_unique_counties  \
# 0                       3                    4                     39
# 1                       0                    2                     15
# 2                       0                    1                      5
# 3                       0                    1                      4
# 4                       2                    2                     32
#
#    mean_hospital_stay_days  max_hospital_stay_days  total_top_diagnosis_codes  \
# 0                 0.000000                     0.0                         12
# 1                 0.000000                     0.0                          7
# 2                 0.205128                     4.0                          3
# 3                 0.763158                     9.0                          4
# 4                 0.000000                     0.0                         10
#
#    mean_total_diagnosis  mean_total_procedures  mean_number_of_physicians  \
# 0              2.663415               0.000000                   1.521951
# 1              2.823529               0.000000                   1.607843
# 2              3.076923               0.076923                   1.538462
# 3              3.105263               0.078947                   1.500000
# 4              2.694737               0.000000                   1.536842
#
#    mean_difference_stay_vs_claim  patients_under_top_attending_physician  \
# 0                            0.0                                       0
# 1                            0.0                                       0
# 2                            0.0                                       0
# 3                            0.0                                       0
# 4                            0.0                                       0
#
#    patients_under_top_operating_physician  mean_claim_amount  \
# 0                                       0         262.390244
# 1                                       0         301.176471
# 2                                       0         698.205128
# 3                                       0        1699.473684
# 4                                       0         324.315789
#
#    total_claim_amount  std_claim_amount   mean_age  count_of_males  \
# 0               53790        609.021752  71.360976              71
# 1               30720        520.835760  73.823529              43
# 2               27230       1934.691424  68.615385              16
# 3               64580       4480.813118  74.342105              23
# 4               61620        673.767191  72.405263              66
#
#    count_of_females  count_of_black_people  count_of_white_people  \
# 0               134                     30                    169
# 1                59                     26                     76
# 2                23                      6                     33
# 3                15                      1                     37
# 4               124                     45                    145
#
#    count_of_hispanic_people  count_of_other_people  count_alzheimer  \
# 0                         4                      2               79
# 1                         0                      0               35
# 2                         0                      0                8
# 3                         0                      0               21
# 4                         0                      0               73
#
#    count_heartfailure  count_kidneydisease  count_cancer  \
# 0                 108                   72            25
# 1                  69                   50            15
# 2                  17                   19             1
# 3                  23                   19             7
# 4                 109                   93            25
#
#    count_obstrpulmonary  count_depression  count_diabetes  \
# 0                    64                91             147
# 1                    37                53              72
# 2                    15                13              29
# 3                    13                18              28
# 4                    61                86             146
#
#    count_ischemicheart  count_osteoporasis  count_rheumatoidarthritis  \
# 0                  151                  61                         54
# 1                   78                  26                         16
# 2                   31                  20                          4
# 3                   28                  14                         10
# 4                  135                  57                         44
#
#    count_stroke  count_renal_disease  mean_annual_inpatient_reimbursement  \
# 0            19                   32                          5180.926829
# 1             8                   10                          3767.549020
# 2             3                   12                          3004.102564
# 3             5                    5                          5268.421053
# 4            13                   41                          4738.947368
#
#    mean_annual_inpatient_deductible  mean_annual_outpatient_reimbursement  \
# 0                        548.253659                           2345.073171
# 1                        479.647059                           2401.666667
# 2                        246.461538                           2441.025641
# 3                        534.000000                           1775.789474
# 4                        534.000000                           2812.947368
#
#    mean_annual_outpatient_deductible  count_inpatient  count_outpatient  \
# 0                         677.951220                0               205
# 1                         605.882353                0               102
# 2                         646.410256                2                37
# 3                         663.947368                6                32
# 4                         826.105263                0               190
#
#    claims_per_bene
# 0         1.213018
# 1         1.259259
# 2         1.300000
# 3         1.520000
# 4         1.301370

# %%
test_df.isna().sum().reset_index().rename(columns={"index": "feature", 0: "missing_values"}).sort_values("missing_values", ascending=False)
# Out:
#                                  feature  missing_values
# 17                      std_claim_amount              49
# 0                               Provider               0
# 2                    count_unique_claims               0
# 1               count_unique_beneficiary               0
# 4                    count_unique_states               0
# ..                                   ...             ...
# 39  mean_annual_outpatient_reimbursement               0
# 40     mean_annual_outpatient_deductible               0
# 41                       count_inpatient               0
# 42                      count_outpatient               0
# 43                       claims_per_bene               0
#
# [44 rows x 2 columns]

# %%
test_df['std_claim_amount'] = test_df['std_claim_amount'].fillna(0)

# %%
provider_id = test_df[['Provider']]
test_df.drop(columns=['Provider'], inplace=True)

# %%
y_test_df = pipe_xgb.predict_proba(test_df)[:, 1]
pd.Series((y_test_df >= 0.50).astype(int)).reset_index()[0].value_counts(normalize=True)
# Out:
# 0
# 0    0.81966
# 1    0.18034
# Name: proportion, dtype: float64

# %%
pd.Series((y_test_df >= 0.20).astype(int)).reset_index()[0].value_counts(normalize=True)
# Out:
# 0
# 0    0.743533
# 1    0.256467
# Name: proportion, dtype: float64
