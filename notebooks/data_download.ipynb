# %%
import kagglehub

# %%
# Download latest version
path = kagglehub.dataset_download("rohitrox/healthcare-provider-fraud-detection-analysis")

print("Path to dataset files:", path)
# Out:
# Downloading from https://www.kaggle.com/api/v1/datasets/download/rohitrox/healthcare-provider-fraud-detection-analysis?dataset_version_number=1...
# 100%|██████████| 25.4M/25.4M [00:01<00:00, 21.2MB/s]
# Extracting files...
# Path to dataset files: /home/nayya/.cache/kagglehub/datasets/rohitrox/healthcare-provider-fraud-detection-analysis/versions/1

# %%
cp -r /home/nayya/.cache/kagglehub/datasets/rohitrox/healthcare-provider-fraud-detection-analysis/versions/1 ./data/
